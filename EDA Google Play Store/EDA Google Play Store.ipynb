# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('googleplaystore.csv')

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
len(df)
# Out:
# 10841

# %%
df['Reviews']= pd.to_numeric(df['Reviews'],errors='coerce')

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
def fix_size(x):
    if x[-1]=='M':
        return float(x[:-1])   
    elif  x[-1]=='K':
        return float(x[:-1]/1024)
    elif x[-1] =='+':
        return float(1)
    else :
        return np.nan

# %%
df['Size'] = df['Size'].apply(fix_size)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            8830 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(3), object(10)
# memory usage: 1.1+ MB

# %%
df['Price']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10836    0
# 10837    0
# 10838    0
# 10839    0
# 10840    0
# Name: Price, Length: 10841, dtype: object

# %%
def fix_price(x):
    try:
        if x.startswith('$'):
            return float(x[1:])
        
        else : 
            return 0.0
    except : 
        return np.nan

# %%
df['Price'] = df['Price'].apply(fix_price)

# %%
fix_price('Everyone')
# Out:
# 0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10840 non-null  float64
#  4   Size            8830 non-null   float64
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  float64
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 1.1+ MB

# %%
df[df['Rating']>5].index
# Out:
# Int64Index([10472], dtype='int64')

# %%
df.drop(index = 10472,inplace=True)

# %%
df[df['Rating']>5]
# Out:
# Empty DataFrame
# Columns: [App, Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %%
df['Type'].value_counts()
# Out:
# Free    10039
# Paid      800
# Name: Type, dtype: int64

# %%
df.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#     Reviews  Size     Installs  Type  Price Content Rating  \
# 0     159.0  19.0      10,000+  Free    0.0       Everyone
# 1     967.0  14.0     500,000+  Free    0.0       Everyone
# 2   87510.0   8.7   5,000,000+  Free    0.0       Everyone
# 3  215644.0  25.0  50,000,000+  Free    0.0           Teen
# 4     967.0   2.8     100,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
df.drop(['Genres','Last Updated','Current Ver'],axis=1,inplace=True)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
def ver_4(x):
    try : 
        if x.startswith('4'):
            return 'Yes'
        else : return 'No'
    except : 
        return np.nan

# %%
ver_4('4.1 and up')
# Out:
# 'Yes'

# %%
df['version 4'] = df['Android Ver'].apply(ver_4)

# %%
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.isna().sum() / len(df) * 100
# Out:
# App                0.000000
# Category           0.000000
# Rating            13.597786
# Reviews            0.000000
# Size              18.551661
# Installs           0.000000
# Type               0.009225
# Price              0.000000
# Content Rating     0.000000
# Android Ver        0.018450
# version 4          0.018450
# dtype: float64

# %%
df.dropna()
# Out:
#                                                      App            Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN
# 1                                    Coloring book moana      ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...      ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint      ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book      ART_AND_DESIGN
# ...                                                  ...                 ...
# 10830                                  News Minecraft.fr  NEWS_AND_MAGAZINES
# 10834                                      FR Calculator              FAMILY
# 10836                                   Sya9a Maroc - FR              FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings              FAMILY
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology           LIFESTYLE
#
# ...

# %%
df[df['Price']==df['Price'].max()]
# Out:
#                            App   Category  Rating  Reviews  Size Installs  \
# 4367  I'm Rich - Trump Edition  LIFESTYLE     3.6    275.0   7.3  10,000+
#
#       Type  Price Content Rating Android Ver version 4
# 4367  Paid  400.0       Everyone  4.1 and up       Yes

# %%
df['Category'].value_counts()
# Out:
# FAMILY                 1972
# GAME                   1144
# TOOLS                   843
# MEDICAL                 463
# BUSINESS                460
# PRODUCTIVITY            424
# PERSONALIZATION         392
# COMMUNICATION           387
# SPORTS                  384
# LIFESTYLE               382
# FINANCE                 366
# HEALTH_AND_FITNESS      341
# PHOTOGRAPHY             335
# SOCIAL                  295
# NEWS_AND_MAGAZINES      283
# SHOPPING                260
# TRAVEL_AND_LOCAL        258
# DATING                  234
# BOOKS_AND_REFERENCE     231
# VIDEO_PLAYERS           175
# EDUCATION               156
# ENTERTAINMENT           149
# MAPS_AND_NAVIGATION     137
# FOOD_AND_DRINK          127
# HOUSE_AND_HOME           88
# AUTO_AND_VEHICLES        85
# LIBRARIES_AND_DEMO       85
# WEATHER                  82
# ART_AND_DESIGN           65
# EVENTS                   64
# PARENTING                60
# COMICS                   60
# BEAUTY                   53
# ...

# %%
df.groupby('Type')['Size'].describe()
# Out:
#        count       mean        std  min    25%   50%   75%    max
# Type
# Free  8175.0  22.345761  22.648567  1.0  5.500  14.0  30.0  100.0
# Paid   654.0  21.330275  22.374559  1.0  4.325  13.0  32.0  100.0

# %%
df[df['Rating']==5].sort_values('Price',ascending=False).head(5)
# Out:
#                                             App Category  Rating  Reviews  \
# 5489                  AP Art History Flashcards   FAMILY     5.0      1.0
# 7477                 USMLE Step 2 CK Flashcards   FAMILY     5.0      1.0
# 5246                      Hey AJ! It's Bedtime!   FAMILY     5.0      1.0
# 7204  TI-84 CE Graphing Calculator Manual TI 84   FAMILY     5.0      1.0
# 5482                 meStudying: AP English Lit   FAMILY     5.0      1.0
#
#       Size Installs  Type  Price Content Rating   Android Ver version 4
# 5489  96.0      10+  Paid  29.99     Mature 17+    4.0 and up       Yes
# 7477  40.0      10+  Paid  19.99       Everyone    2.2 and up        No
# 5246  63.0      10+  Paid   4.99       Everyone    2.3 and up        No
# 7204  27.0     100+  Paid   4.99       Everyone    4.1 and up       Yes
# 5482   NaN      10+  Paid   4.99       Everyone  2.0.1 and up        No

# %%
len(df[df['Reviews']>50000])
# Out:
# 2782

# %%
df.groupby(['Category','Installs'])['Price'].mean()
# Out:
# Category        Installs
# ART_AND_DESIGN  0+             0.000000
#                 1,000+         0.663333
#                 1,000,000+     0.000000
#                 10,000+        0.180909
#                 10,000,000+    0.000000
#                                  ...
# WEATHER         5,000,000+     0.000000
#                 50,000+        0.000000
#                 50,000,000+    0.000000
#                 500+           1.660000
#                 500,000+       0.855714
# Name: Price, Length: 515, dtype: float64

# %%
len(df[df['Rating']>4.7])
# Out:
# 595

# %%
df[df['Rating']>4.7].describe()
# Out:
#            Rating       Reviews        Size       Price
# count  595.000000  5.950000e+02  558.000000  595.000000
# mean     4.906723  4.353970e+04   17.652867    0.501849
# std      0.092233  2.590468e+05   19.903999    2.252596
# min      4.800000  1.000000e+00    1.000000    0.000000
# 25%      4.800000  4.000000e+00    4.200000    0.000000
# 50%      4.900000  1.600000e+01   10.000000    0.000000
# 75%      5.000000  4.660000e+02   23.000000    0.000000
# max      5.000000  4.559407e+06   96.000000   29.990000

# %%
df[df['Installs']=='5,000,000+']['Price'].sum()
# Out:
# 0.0

# %%
df.groupby('Type')['Size'].describe()
# Out:
#        count       mean        std  min    25%   50%   75%    max
# Type
# Free  8175.0  22.345761  22.648567  1.0  5.500  14.0  30.0  100.0
# Paid   654.0  21.330275  22.374559  1.0  4.325  13.0  32.0  100.0

# %%
sns.heatmap(df.corr(),annot=True,linewidths=1.5,cmap='mako')

# %%
pd.pivot_table(values='Price',index='Category',columns='Installs',data=df)
# Out:
# Installs               0       0+          1+     1,000+  1,000,000+  \
# Category
# ART_AND_DESIGN       NaN    0.000         NaN   0.663333    0.000000
# AUTO_AND_VEHICLES    NaN      NaN    0.000000   0.000000    0.000000
# BEAUTY               NaN      NaN         NaN   0.000000    0.000000
# BOOKS_AND_REFERENCE  NaN      NaN    5.990000   0.149118    0.000000
# BUSINESS             NaN    0.000    0.000000   0.183265    0.000000
# COMICS               NaN      NaN         NaN   0.000000    0.000000
# COMMUNICATION        NaN      NaN    0.000000   0.294091    0.066444
# DATING               NaN      NaN    0.000000   0.411176    0.000000
# EDUCATION            NaN      NaN         NaN   4.990000    0.000000
# ENTERTAINMENT        NaN      NaN         NaN        NaN    0.000000
# EVENTS               NaN      NaN  109.990000   0.000000    0.000000
# FAMILY               0.0    2.490    0.846000   0.511674    0.036182
# ...

# %%
sns.clustermap(df.corr(),annot=True)
